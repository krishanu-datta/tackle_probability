# %% [markdown]
# ## Import Data

# %%
# import packages and set options

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from datetime import datetime
pd.set_option('display.max_rows', 20)

# %%
# read data in

games_df = pd.read_csv('../data/games.csv')
players_df = pd.read_csv('../data/players.csv')
plays_df = pd.read_csv('../data/plays.csv')
tackles_df = pd.read_csv('../data/tackles.csv')
tracking_week_1_df = pd.read_csv('../data/tracking_week_1.csv')
tracking_week_2_df = pd.read_csv('../data/tracking_week_2.csv')
tracking_week_3_df = pd.read_csv('../data/tracking_week_3.csv')
tracking_week_4_df = pd.read_csv('../data/tracking_week_4.csv')
tracking_week_5_df = pd.read_csv('../data/tracking_week_5.csv')
tracking_week_6_df = pd.read_csv('../data/tracking_week_6.csv')
tracking_week_7_df = pd.read_csv('../data/tracking_week_7.csv')
#tracking_week_8_df = pd.read_csv('tracking_week_8.csv')
#tracking_week_9_df = pd.read_csv('tracking_week_9.csv')

# %%
# append all tracking data into one dataframe
tracking_df = tracking_week_1_df.append(tracking_week_2_df, ignore_index=True)
tracking_df = tracking_df.append(tracking_week_3_df, ignore_index=True)
tracking_df = tracking_df.append(tracking_week_4_df, ignore_index=True)
tracking_df = tracking_df.append(tracking_week_5_df, ignore_index=True)
tracking_df = tracking_df.append(tracking_week_6_df, ignore_index=True)
tracking_df = tracking_df.append(tracking_week_7_df, ignore_index=True)
# Out:
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_week_1_df.append(tracking_week_2_df, ignore_index=True)
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_df.append(tracking_week_3_df, ignore_index=True)
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_df.append(tracking_week_4_df, ignore_index=True)
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_df.append(tracking_week_5_df, ignore_index=True)
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_df.append(tracking_week_6_df, ignore_index=True)
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\690392032.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tracking_df = tracking_df.append(tracking_week_7_df, ignore_index=True)

# %% [markdown]
# ## Data Preprocessing and Basic Feature Engineering

# %%
## players_df edits

# converting heights

# height dictionary
height_mapping = {'5-10': 70, '5-11': 71, '5-6': 66, '5-7': 67, '5-8': 68,
                  '5-9': 69, '6-0': 72, '6-1': 73, '6-2': 74, '6-3': 75,
                  '6-4': 76, '6-5': 77, '6-6': 78, '6-7': 79, '6-8': 80, '6-9': 81}

def height_to_inches(height_str):
    return height_mapping[height_str]

# Apply the function to create a new 'height_in_inch' column
players_df['height_in_inch'] = players_df['height'].apply(height_to_inches)

# converting ages

# Convert birthdates to datetime objects
birthdates_datetime = pd.to_datetime(players_df['birthDate'], errors='coerce')

# Calculate age based on current date
current_date = datetime.now()
ages = (current_date - birthdates_datetime).dt.days / 365.25

# Create a DataFrame with birthdates and ages
players_df['age'] = ages

# creating position groups

# size based / traditional mapping
position_group_mapping = {'C' : 'OL', 'CB' : 'DB', 'DB': 'DB', 'DE' : 'DL', 'DT': 'DL', 'FB' : 'HB',
                  'FS': 'DB', 'G': 'OL', 'ILB' : 'LB', 'LS': 'OL', 'MLB': 'LB', 'NT': 'DL',
                  'OLB': 'LB', 'QB': 'QB', 'RB': 'HB', 'SS': 'DB', 'T': 'OL', 'TE' : 'R', 'WR' : 'R'}

# role based mapping
position_role_mapping = {'C' : 'OL', 'CB' : 'CB', 'DB': 'DB', 'DE' : 'EDGE', 'DT': 'DL', 'FB' : 'TE',
                  'FS': 'DB', 'G': 'OL', 'ILB' : 'LB', 'LS': 'OL', 'MLB': 'LB', 'NT': 'DL',
                  'OLB': 'EDGE', 'QB': 'QB', 'RB': 'HB', 'SS': 'DB', 'T': 'OL', 'TE' : 'TE', 'WR' : 'WR'}


def position_to_pos_group(position):
    return position_group_mapping[position]

def position_to_pos_role(position):
    return position_role_mapping[position]

players_df['position_group'] = players_df['position'].apply(position_to_pos_group)
players_df['position_role'] = players_df['position'].apply(position_to_pos_role)

# select relevant columns
players_df_set = players_df[['nflId','height_in_inch', 'weight',
                         'position','position_group','position_role','displayName']]

# %%
# plays_df edits

def calculate_time_remaining(quarter, gameclock):
    def convert_to_seconds(gameclock_str):
        minutes, seconds = map(int, gameclock_str.split(':'))
        return minutes * 60 + seconds

    # Convert 'gameclock' to total seconds
    total_seconds = gameclock.apply(convert_to_seconds)

    # Adjust time based on 'quarter'
    adjusted_time = total_seconds + (4 - quarter) * 900

    return adjusted_time

plays_df['time_remaining'] = calculate_time_remaining(plays_df['quarter'], plays_df['gameClock'])

# drop plays nullified by penalty
plays_df = plays_df[plays_df["playNullifiedByPenalty"] == 'N']

plays_df_set = plays_df[['gameId', 'playId','ballCarrierId', 'ballCarrierDisplayName', 
                         'quarter', 'down', 'yardsToGo', 'time_remaining',
                    'absoluteYardlineNumber', 'gameClock', 'preSnapHomeScore', 'preSnapVisitorScore',
                    'passLength', 'offenseFormation', 'defendersInTheBox', 'passProbability',
                    'preSnapHomeTeamWinProbability', 'preSnapVisitorTeamWinProbability','defensiveTeam']]

# %%
plays_df = pd.read_csv('../../data/plays.csv')
pd.set_option('display.max_columns', None)
plays_df
# Out:
#            gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0      2022100908    3537          48723           Parker Hesse
# 1      2022091103    3126          52457         Chase Claypool
# 2      2022091111    1148          42547          Darren Waller
# 3      2022100212    2007          46461             Mike Boone
# 4      2022091900    1372          47857       Devin Singletary
# ...           ...     ...            ...                    ...
# 12481  2022100204     123          43293        Ezekiel Elliott
# 12482  2022091200    3467          46189            Will Dissly
# 12483  2022101605    3371          44860              Joe Mixon
# 12484  2022100207    2777          52449        Jonathan Taylor
# 12485  2022102308     905          54572          Dameon Pierce
#
#                                          playDescription  quarter  down  \
# 0      (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1      (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2      (8:57) D.Carr pass short middle to D.Waller to...        2     2
# 3      (13:12) M.Boone left tackle to DEN 44 for 7 ya...        3     2
# 4      (8:33) D.Singletary right guard to TEN 32 for ...        2     1
# ...                                                  ...      ...   ...
# 12481  (13:31) E.Elliott right tackle to WAS 38 for 1...        1     1
# 12482  (6:08) G.Smith pass short right to W.Dissly to...        4     1
# 12483  (9:35) (Shotgun) J.Mixon left end to CIN 47 fo...        4     1
# 12484  (2:02) (Shotgun) J.Taylor up the middle to TEN...        3     1
# 12485  (12:51) C.Heck reported in as eligible.  D.Pie...        2     3
#
#        yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber  \
# 0             10            ATL            TB          ATL              41
# 1             10            PIT           CIN          PIT              34
# 2              5             LV           LAC           LV              30
# 3             10            DEN            LV          DEN              37
# 4             10            BUF           TEN          TEN              35
# ...          ...            ...           ...          ...             ...
# 12481         10            DAL           WAS          WAS              39
# 12482         10            SEA           DEN          SEA              30
# 12483         10            CIN            NO          CIN              41
# 12484         10            IND           TEN          TEN              34
# 12485          1            HOU            LV           LV              17
#
#       gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  \
# 0          7:52                21                    7          C         6.0
# 1          7:38                14                   20        NaN         NaN
# 2          8:57                10                    3          C        11.0
# 3         13:12                19                   16        NaN         NaN
# 4          8:33                 7                    7        NaN         NaN
# ...         ...               ...                  ...        ...         ...
# 12481     13:31                 0                    0        NaN         NaN
# 12482      6:08                17                   16          C         0.0
# 12483      9:35                26                   21        NaN         NaN
# 12484      2:02                17                   24        NaN         NaN
# 12485     12:51                 3                    0        NaN         NaN
#
#        penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  \
# 0               NaN                     9           9                      N
# 1               NaN                     3           3                      N
# 2               NaN                    15          15                      N
# 3               NaN                     7           7                      N
# 4               NaN                     3           3                      N
# ...             ...                   ...         ...                    ...
# 12481           NaN                     1           1                      N
# 12482           NaN                     2           2                      N
# 12483           NaN                     6           6                      N
# 12484           NaN                    -2          -2                      N
# 12485           NaN                     3           3                      N
#
#        absoluteYardlineNumber offenseFormation  defendersInTheBox  \
# 0                          69          SHOTGUN                7.0
# 1                          76          SHOTGUN                7.0
# 2                          40           I_FORM                6.0
# 3                          47       SINGLEBACK                6.0
# 4                          75           I_FORM                7.0
# ...                       ...              ...                ...
# 12481                      49       SINGLEBACK                6.0
# 12482                      40       SINGLEBACK                7.0
# 12483                      69          SHOTGUN                6.0
# 12484                      44          SHOTGUN                6.0
# 12485                      27           I_FORM                8.0
#
#        passProbability  preSnapHomeTeamWinProbability  \
# 0             0.747284                       0.976785
# 1             0.416454                       0.160485
# 2             0.267933                       0.756661
# 3             0.592704                       0.620552
# 4             0.470508                       0.836290
# ...                ...                            ...
# 12481         0.577800                       0.638600
# 12482         0.298983                       0.615241
# 12483         0.639439                       0.667054
# 12484         0.518695                       0.410611
# 12485         0.101552                       0.726639
#
#        preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  \
# 0                              0.023215                    -0.006110
# 1                              0.839515                    -0.010865
# 2                              0.243339                    -0.037409
# 3                              0.379448                    -0.002451
# 4                              0.163710                     0.001053
# ...                                 ...                          ...
# 12481                          0.361400                    -0.011542
# 12482                          0.384759                    -0.025458
# 12483                          0.332946                    -0.005164
# 12484                          0.589389                    -0.046648
# 12485                          0.273361                    -0.015028
#
#        visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded  \
# 0                          0.006110        2.360609             0.981955
# 1                          0.010865        1.733344            -0.263424
# 2                          0.037409        1.312855             1.133666
# 3                          0.002451        1.641006            -0.043580
# 4                         -0.001053        3.686428            -0.167903
# ...                             ...             ...                  ...
# 12481                      0.011542        3.642571            -0.504018
# 12482                      0.025458        1.434580            -0.444642
# 12483                      0.005164        2.115356             0.203819
# 12484                      0.046648        3.946232            -0.976039
# 12485                      0.015028        4.685974             0.251580
#
#       foulName1 foulName2  foulNFLId1  foulNFLId2
# 0           NaN       NaN         NaN         NaN
# 1           NaN       NaN         NaN         NaN
# 2           NaN       NaN         NaN         NaN
# 3           NaN       NaN         NaN         NaN
# 4           NaN       NaN         NaN         NaN
# ...         ...       ...         ...         ...
# 12481       NaN       NaN         NaN         NaN
# 12482       NaN       NaN         NaN         NaN
# 12483       NaN       NaN         NaN         NaN
# 12484       NaN       NaN         NaN         NaN
# 12485       NaN       NaN         NaN         NaN
#
# [12486 rows x 35 columns]

# %%
# tackles_df edits

tackles_df = tackles_df.sort_values(by=['gameId', 'playId'])
tackles_df['season_rolling_tackle_ct'] = tackles_df.groupby('nflId')['tackle'].cumsum()
tackles_df['game_rolling_tackle_ct'] = tackles_df.groupby(['gameId', 'nflId'])['tackle'].cumsum()
tackles_df['season_rolling_missed_tackle_ct'] = tackles_df.groupby('nflId')['pff_missedTackle'].cumsum()
tackles_df['game_rolling_missed_tackle_ct'] = tackles_df.groupby(['gameId', 'nflId'])['pff_missedTackle'].cumsum()

tackles_df_set = tackles_df[['gameId', 'playId', 'nflId','tackle', 'assist', 'forcedFumble', 'pff_missedTackle',
                            'season_rolling_tackle_ct','game_rolling_tackle_ct','season_rolling_missed_tackle_ct','game_rolling_missed_tackle_ct']]

# %%
# take subset of tracking_df

tracking_df_set = tracking_df[['gameId', 'playId', 'nflId', 'displayName', 'frameId', 'time'
                               , 'club', 'playDirection', 'x', 'y', 's', 'a', 'dis', 'o','dir', 'event']]

# %%
# merge all available data to tracking data

one_merge = pd.merge(tracking_df_set, games_df, on='gameId')
two_merge = pd.merge(one_merge, players_df_set, on='nflId')
three_merge = pd.merge(two_merge, plays_df_set, on=['gameId', 'playId'])
final_merge = pd.merge(three_merge, tackles_df_set, on=['gameId', 'playId', 'nflId'], how="left")

final_merge.head()

# dropping about 61193 frames because of missing/unexplained data
# tracking_week_1_df[tracking_week_1_df["displayName"] == "football"]
# Out:
#        gameId  playId    nflId   displayName_x  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        6
# 1  2022090800      56  38577.0    Bobby Wagner        6
# 2  2022090800      56  41239.0    Aaron Donald        6
# 3  2022090800      56  42392.0     Mitch Morse        6
# 4  2022090800      56  42489.0    Stefon Diggs        6
#
#                          time club playDirection      x      y     s     a  \
# 0  2022-09-08 20:24:05.700000  BUF          left  88.80  26.70  1.15  1.42
# 1  2022-09-08 20:24:05.700000   LA          left  78.11  28.74  3.35  2.62
# 2  2022-09-08 20:24:05.700000   LA          left  92.15  29.96  3.62  2.86
# 3  2022-09-08 20:24:05.700000  BUF          left  88.21  29.31  1.42  0.64
# 4  2022-09-08 20:24:05.700000  BUF          left  79.85  35.59  4.61  4.82
#
#     dis       o     dir                event  season  week    gameDate  \
# 0  0.12  234.48  139.41  pass_outcome_caught    2022     1  09/08/2022
# 1  0.32  349.47  357.71  pass_outcome_caught    2022     1  09/08/2022
# 2  0.37  186.16  157.65  pass_outcome_caught    2022     1  09/08/2022
# 3  0.14  282.32  347.15  pass_outcome_caught    2022     1  09/08/2022
# 4  0.45  114.27  202.20  pass_outcome_caught    2022     1  09/08/2022
#
#   gameTimeEastern homeTeamAbbr visitorTeamAbbr  homeFinalScore  \
# 0        20:20:00           LA             BUF              10
# 1        20:20:00           LA             BUF              10
# 2        20:20:00           LA             BUF              10
# 3        20:20:00           LA             BUF              10
# 4        20:20:00           LA             BUF              10
#
#    visitorFinalScore  height_in_inch  weight position position_group  \
# 0                 31              77     325        G             OL
# 1                 31              72     242      ILB             LB
# 2                 31              73     280       DT             DL
# 3                 31              78     305        C             OL
# 4                 31              72     191       WR              R
#
#   position_role   displayName_y  ballCarrierId ballCarrierDisplayName  \
# 0            OL  Rodger Saffold          42489           Stefon Diggs
# 1            LB    Bobby Wagner          42489           Stefon Diggs
# 2            DL    Aaron Donald          42489           Stefon Diggs
# 3            OL     Mitch Morse          42489           Stefon Diggs
# 4            WR    Stefon Diggs          42489           Stefon Diggs
#
#    quarter  down  yardsToGo  time_remaining  absoluteYardlineNumber gameClock  \
# 0        1     1         10            3600                      85     15:00
# 1        1     1         10            3600                      85     15:00
# 2        1     1         10            3600                      85     15:00
# 3        1     1         10            3600                      85     15:00
# 4        1     1         10            3600                      85     15:00
#
#    preSnapHomeScore  preSnapVisitorScore  passLength offenseFormation  \
# 0                 0                    0         5.0          SHOTGUN
# 1                 0                    0         5.0          SHOTGUN
# 2                 0                    0         5.0          SHOTGUN
# 3                 0                    0         5.0          SHOTGUN
# 4                 0                    0         5.0          SHOTGUN
#
#    defendersInTheBox  passProbability  preSnapHomeTeamWinProbability  \
# 0                6.0          0.68996                       0.413347
# 1                6.0          0.68996                       0.413347
# 2                6.0          0.68996                       0.413347
# 3                6.0          0.68996                       0.413347
# 4                6.0          0.68996                       0.413347
#
#    preSnapVisitorTeamWinProbability defensiveTeam  tackle  assist  \
# 0                          0.586653            LA     NaN     NaN
# 1                          0.586653            LA     NaN     NaN
# 2                          0.586653            LA     NaN     NaN
# 3                          0.586653            LA     NaN     NaN
# 4                          0.586653            LA     NaN     NaN
#
#    forcedFumble  pff_missedTackle  season_rolling_tackle_ct  \
# 0           NaN               NaN                       NaN
# 1           NaN               NaN                       NaN
# 2           NaN               NaN                       NaN
# 3           NaN               NaN                       NaN
# 4           NaN               NaN                       NaN
#
#    game_rolling_tackle_ct  season_rolling_missed_tackle_ct  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    game_rolling_missed_tackle_ct
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
# filter by frames in which the pass is caught
pass_caught = final_merge[final_merge['event'] == 'pass_outcome_caught']

# %%
# join all players to ball carrier information

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
joined_with_bc = pd.merge(pass_caught,
                          final_merge[['displayName_x','gameId', 'playId', 'frameId','x', 'y', 's', 'a',
            'dis', 'o', 'dir', 'weight', 'position', 'nflId', 'height_in_inch', 'position_group','position_role']],
                     left_on=['gameId', 'playId', 'frameId', 'ballCarrierId'],
                     right_on=['gameId', 'playId', 'frameId', 'nflId'],
                     how='left', suffixes=('_defense', '_offense'))
joined_with_bc.head(5)
# Out:
#        gameId  playId  nflId_defense displayName_x_defense  frameId  \
# 0  2022090800      56        35472.0        Rodger Saffold        6
# 1  2022090800      56        38577.0          Bobby Wagner        6
# 2  2022090800      56        41239.0          Aaron Donald        6
# 3  2022090800      56        42392.0           Mitch Morse        6
# 4  2022090800      56        42489.0          Stefon Diggs        6
#
#                          time club playDirection  x_defense  y_defense  \
# 0  2022-09-08 20:24:05.700000  BUF          left      88.80      26.70
# 1  2022-09-08 20:24:05.700000   LA          left      78.11      28.74
# 2  2022-09-08 20:24:05.700000   LA          left      92.15      29.96
# 3  2022-09-08 20:24:05.700000  BUF          left      88.21      29.31
# 4  2022-09-08 20:24:05.700000  BUF          left      79.85      35.59
#
#    s_defense  a_defense  dis_defense  o_defense  dir_defense  \
# 0       1.15       1.42         0.12     234.48       139.41
# 1       3.35       2.62         0.32     349.47       357.71
# 2       3.62       2.86         0.37     186.16       157.65
# 3       1.42       0.64         0.14     282.32       347.15
# 4       4.61       4.82         0.45     114.27       202.20
#
#                  event  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  pass_outcome_caught    2022     1  09/08/2022        20:20:00           LA
# 1  pass_outcome_caught    2022     1  09/08/2022        20:20:00           LA
# 2  pass_outcome_caught    2022     1  09/08/2022        20:20:00           LA
# 3  pass_outcome_caught    2022     1  09/08/2022        20:20:00           LA
# 4  pass_outcome_caught    2022     1  09/08/2022        20:20:00           LA
#
#   visitorTeamAbbr  homeFinalScore  visitorFinalScore  height_in_inch_defense  \
# 0             BUF              10                 31                      77
# 1             BUF              10                 31                      72
# 2             BUF              10                 31                      73
# 3             BUF              10                 31                      78
# 4             BUF              10                 31                      72
#
#    weight_defense position_defense position_group_defense  \
# 0             325                G                     OL
# 1             242              ILB                     LB
# 2             280               DT                     DL
# 3             305                C                     OL
# 4             191               WR                      R
#
#   position_role_defense   displayName_y  ballCarrierId ballCarrierDisplayName  \
# 0                    OL  Rodger Saffold          42489           Stefon Diggs
# 1                    LB    Bobby Wagner          42489           Stefon Diggs
# 2                    DL    Aaron Donald          42489           Stefon Diggs
# 3                    OL     Mitch Morse          42489           Stefon Diggs
# 4                    WR    Stefon Diggs          42489           Stefon Diggs
#
#    quarter  down  yardsToGo  time_remaining  absoluteYardlineNumber gameClock  \
# 0        1     1         10            3600                      85     15:00
# 1        1     1         10            3600                      85     15:00
# 2        1     1         10            3600                      85     15:00
# 3        1     1         10            3600                      85     15:00
# 4        1     1         10            3600                      85     15:00
#
#    preSnapHomeScore  preSnapVisitorScore  passLength offenseFormation  \
# 0                 0                    0         5.0          SHOTGUN
# 1                 0                    0         5.0          SHOTGUN
# 2                 0                    0         5.0          SHOTGUN
# 3                 0                    0         5.0          SHOTGUN
# 4                 0                    0         5.0          SHOTGUN
#
#    defendersInTheBox  passProbability  preSnapHomeTeamWinProbability  \
# 0                6.0          0.68996                       0.413347
# 1                6.0          0.68996                       0.413347
# 2                6.0          0.68996                       0.413347
# 3                6.0          0.68996                       0.413347
# 4                6.0          0.68996                       0.413347
#
#    preSnapVisitorTeamWinProbability defensiveTeam  tackle  assist  \
# 0                          0.586653            LA     NaN     NaN
# 1                          0.586653            LA     NaN     NaN
# 2                          0.586653            LA     NaN     NaN
# 3                          0.586653            LA     NaN     NaN
# 4                          0.586653            LA     NaN     NaN
#
#    forcedFumble  pff_missedTackle  season_rolling_tackle_ct  \
# 0           NaN               NaN                       NaN
# 1           NaN               NaN                       NaN
# 2           NaN               NaN                       NaN
# 3           NaN               NaN                       NaN
# 4           NaN               NaN                       NaN
#
#    game_rolling_tackle_ct  season_rolling_missed_tackle_ct  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    game_rolling_missed_tackle_ct displayName_x_offense  x_offense  y_offense  \
# 0                            NaN          Stefon Diggs      79.85      35.59
# 1                            NaN          Stefon Diggs      79.85      35.59
# 2                            NaN          Stefon Diggs      79.85      35.59
# 3                            NaN          Stefon Diggs      79.85      35.59
# 4                            NaN          Stefon Diggs      79.85      35.59
#
#    s_offense  a_offense  dis_offense  o_offense  dir_offense  weight_offense  \
# 0       4.61       4.82         0.45     114.27        202.2             191
# 1       4.61       4.82         0.45     114.27        202.2             191
# 2       4.61       4.82         0.45     114.27        202.2             191
# 3       4.61       4.82         0.45     114.27        202.2             191
# 4       4.61       4.82         0.45     114.27        202.2             191
#
#   position_offense  nflId_offense  height_in_inch_offense  \
# 0               WR        42489.0                      72
# 1               WR        42489.0                      72
# 2               WR        42489.0                      72
# 3               WR        42489.0                      72
# 4               WR        42489.0                      72
#
#   position_group_offense position_role_offense
# 0                      R                    WR
# 1                      R                    WR
# 2                      R                    WR
# 3                      R                    WR
# 4                      R                    WR

# %%
#defense_only = joined_with_bc[joined_with_bc['club'] == joined_with_bc['defensiveTeam']]

joined_with_bc["offense_score"] = np.where(joined_with_bc['homeTeamAbbr'] == joined_with_bc['defensiveTeam'],
                                           joined_with_bc["preSnapVisitorScore"], joined_with_bc["preSnapHomeScore"])
joined_with_bc["defense_score"] = np.where(joined_with_bc['homeTeamAbbr'] == joined_with_bc['defensiveTeam'],
                                           joined_with_bc["preSnapHomeScore"], joined_with_bc["preSnapVisitorScore"])
joined_with_bc["differential"] = joined_with_bc["defense_score"] - joined_with_bc["offense_score"]

joined_with_bc["offense_win_prob"] = np.where(joined_with_bc['homeTeamAbbr'] == joined_with_bc['defensiveTeam'],
                                           joined_with_bc["preSnapVisitorTeamWinProbability"], joined_with_bc["preSnapHomeTeamWinProbability"])
joined_with_bc["defense_win_prob"] = np.where(joined_with_bc['homeTeamAbbr'] == joined_with_bc['defensiveTeam'],
                                           joined_with_bc["preSnapHomeTeamWinProbability"], joined_with_bc["preSnapVisitorTeamWinProbability"])
joined_with_bc["prob_differential"] = joined_with_bc["defense_win_prob"] - joined_with_bc["offense_win_prob"]

# %%
# distance to ball carrier
def calculate_distance(row):
    return ((row['x_defense'] - row['x_offense'])**2 + (row['y_defense'] - row['y_offense'])**2)**0.5

# Apply the function to create a new column 'distance'
joined_with_bc['dist_to_bc'] = joined_with_bc.apply(calculate_distance, axis=1)

# adds column for defense
joined_with_bc['is_defense'] = (joined_with_bc['club'] == joined_with_bc['defensiveTeam']).astype(int)

# number of offensive obstacles
#joined_with_bc['num_blockers'] = joined_with_bc[joined_with_bc['is_defense'] == 0].groupby('playId')['dist_to_bc'].transform(lambda x: x.lt(joined_with_bc.loc[joined_with_bc['is_defense'] == 1, 'dist_to_bc']).sum())

# create offense defense subsets
#offensive_players = joined_with_bc[joined_with_bc['is_defense'] == 0]
defensive_players = joined_with_bc[joined_with_bc['is_defense'] == 1]

# weight of offensive obstacles
#joined_with_bc['total_weight_blockers'] = offensive_players.groupby('playId')['weight_offense'].transform(
#    lambda x: x.where(joined_with_bc['dist_to_bc'].lt(joined_with_bc.loc[joined_with_bc['is_defense'] == 1, 'dist_to_bc'])).sum()
#)

# If you want to fill NaN with 0 for those who are not closer, you can do:
#joined_with_bc['total_weight_blockers'].fillna(0, inplace=True)

defensive_players = joined_with_bc[joined_with_bc['is_defense'] == 1]
# rank amongst defenders
defensive_players['rank_to_bc'] = defensive_players.groupby(['playId','gameId'])['dist_to_bc'].rank()
# Out:
# C:\Users\PC User\AppData\Local\Temp\ipykernel_40544\648836471.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defensive_players['rank_to_bc'] = defensive_players.groupby(['playId','gameId'])['dist_to_bc'].rank()

# %% [markdown]
# ## TARGET VARIABLE ENGINEERING

# %%
defensive_players
# Out:
#            gameId  playId  nflId_defense displayName_x_defense  frameId  \
# 1      2022090800      56        38577.0          Bobby Wagner        6
# 2      2022090800      56        41239.0          Aaron Donald        6
# 5      2022090800      56        42816.0             Troy Hill        6
# 6      2022090800      56        43294.0          Jalen Ramsey        6
# 7      2022090800      56        43298.0         Leonard Floyd        6
# ...           ...     ...            ...                   ...      ...
# 97078  2022091200    3826        43436.0     Quinton Jefferson        6
# 97079  2022091200    3826        42827.0        Justin Coleman        6
# 97080  2022091200    3826        44873.0            Josh Jones        6
# 97083  2022091200    3826        54505.0             Boye Mafe        6
# 97085  2022091200    3826        46711.0             Ryan Neal        6
#
#                              time club playDirection  x_defense  y_defense  \
# 1      2022-09-08 20:24:05.700000   LA          left      78.11      28.74
# 2      2022-09-08 20:24:05.700000   LA          left      92.15      29.96
# 5      2022-09-08 20:24:05.700000   LA          left      70.62       7.66
# 6      2022-09-08 20:24:05.700000   LA          left      78.15      37.85
# 7      2022-09-08 20:24:05.700000   LA          left      92.11      33.14
# ...                           ...  ...           ...        ...        ...
# 97078  2022-09-12 23:05:53.500000  SEA          left      69.03      28.24
# 97079  2022-09-12 23:05:53.500000  SEA          left      60.59      12.24
# 97080  2022-09-12 23:05:53.500000  SEA          left      49.62      32.42
# 97083  2022-09-12 23:05:53.500000  SEA          left      71.56      25.09
# 97085  2022-09-12 23:05:53.500000  SEA          left      35.04      38.82
#
#        s_defense  a_defense  dis_defense  o_defense  dir_defense  \
# 1           3.35       2.62         0.32     349.47       357.71
# 2           3.62       2.86         0.37     186.16       157.65
# 5           2.60       4.14         0.27     331.57       278.33
# 6           5.88       1.23         0.59     140.96       178.50
# 7           1.34       2.21         0.13     159.12       203.53
# ...          ...        ...          ...        ...          ...
# 97078       3.50       0.92         0.36     112.81       184.46
# 97079       6.30       2.68         0.63     103.59       136.76
# 97080       4.63       4.05         0.44     143.62       159.31
# 97083       4.80       3.11         0.47     183.52       187.27
# 97085       2.61       6.42         0.26     132.69       212.57
#
#                      event  season  week    gameDate gameTimeEastern  \
# 1      pass_outcome_caught    2022     1  09/08/2022        20:20:00
# 2      pass_outcome_caught    2022     1  09/08/2022        20:20:00
# 5      pass_outcome_caught    2022     1  09/08/2022        20:20:00
# 6      pass_outcome_caught    2022     1  09/08/2022        20:20:00
# 7      pass_outcome_caught    2022     1  09/08/2022        20:20:00
# ...                    ...     ...   ...         ...             ...
# 97078  pass_outcome_caught    2022     1  09/12/2022        20:15:00
# 97079  pass_outcome_caught    2022     1  09/12/2022        20:15:00
# 97080  pass_outcome_caught    2022     1  09/12/2022        20:15:00
# 97083  pass_outcome_caught    2022     1  09/12/2022        20:15:00
# 97085  pass_outcome_caught    2022     1  09/12/2022        20:15:00
#
#       homeTeamAbbr visitorTeamAbbr  homeFinalScore  visitorFinalScore  \
# 1               LA             BUF              10                 31
# 2               LA             BUF              10                 31
# 5               LA             BUF              10                 31
# 6               LA             BUF              10                 31
# 7               LA             BUF              10                 31
# ...            ...             ...             ...                ...
# 97078          SEA             DEN              17                 16
# 97079          SEA             DEN              17                 16
# 97080          SEA             DEN              17                 16
# 97083          SEA             DEN              17                 16
# 97085          SEA             DEN              17                 16
#
#        height_in_inch_defense  weight_defense position_defense  \
# 1                          72             242              ILB
# 2                          73             280               DT
# 5                          71             184               CB
# 6                          73             208               CB
# 7                          77             240               DE
# ...                       ...             ...              ...
# 97078                      76             291               DE
# 97079                      71             190               CB
# 97080                      74             220               FS
# 97083                      76             265              OLB
# 97085                      75             200               SS
#
#       position_group_defense position_role_defense      displayName_y  \
# 1                         LB                    LB       Bobby Wagner
# 2                         DL                    DL       Aaron Donald
# 5                         DB                    CB          Troy Hill
# 6                         DB                    CB       Jalen Ramsey
# 7                         DL                  EDGE      Leonard Floyd
# ...                      ...                   ...                ...
# 97078                     DL                  EDGE  Quinton Jefferson
# 97079                     DB                    CB     Justin Coleman
# 97080                     DB                    DB         Josh Jones
# 97083                     LB                  EDGE          Boye Mafe
# 97085                     DB                    DB          Ryan Neal
#
#        ballCarrierId ballCarrierDisplayName  quarter  down  yardsToGo  \
# 1              42489           Stefon Diggs        1     1         10
# 2              42489           Stefon Diggs        1     1         10
# 5              42489           Stefon Diggs        1     1         10
# 6              42489           Stefon Diggs        1     1         10
# 7              42489           Stefon Diggs        1     1         10
# ...              ...                    ...      ...   ...        ...
# 97078          53464       Javonte Williams        4     3         14
# 97079          53464       Javonte Williams        4     3         14
# 97080          53464       Javonte Williams        4     3         14
# 97083          53464       Javonte Williams        4     3         14
# 97085          53464       Javonte Williams        4     3         14
#
#        time_remaining  absoluteYardlineNumber gameClock  preSnapHomeScore  \
# 1                3600                      85     15:00                 0
# 2                3600                      85     15:00                 0
# 5                3600                      85     15:00                 0
# 6                3600                      85     15:00                 0
# 7                3600                      85     15:00                 0
# ...               ...                     ...       ...               ...
# 97078              71                      65      1:11                17
# 97079              71                      65      1:11                17
# 97080              71                      65      1:11                17
# 97083              71                      65      1:11                17
# 97085              71                      65      1:11                17
#
#        preSnapVisitorScore  passLength offenseFormation  defendersInTheBox  \
# 1                        0         5.0          SHOTGUN                6.0
# 2                        0         5.0          SHOTGUN                6.0
# 5                        0         5.0          SHOTGUN                6.0
# 6                        0         5.0          SHOTGUN                6.0
# 7                        0         5.0          SHOTGUN                6.0
# ...                    ...         ...              ...                ...
# 97078                   16        -6.0          SHOTGUN                3.0
# 97079                   16        -6.0          SHOTGUN                3.0
# 97080                   16        -6.0          SHOTGUN                3.0
# 97083                   16        -6.0          SHOTGUN                3.0
# 97085                   16        -6.0          SHOTGUN                3.0
#
#        passProbability  preSnapHomeTeamWinProbability  \
# 1             0.689960                       0.413347
# 2             0.689960                       0.413347
# 5             0.689960                       0.413347
# 6             0.689960                       0.413347
# 7             0.689960                       0.413347
# ...                ...                            ...
# 97078         0.916875                       0.508994
# 97079         0.916875                       0.508994
# 97080         0.916875                       0.508994
# 97083         0.916875                       0.508994
# 97085         0.916875                       0.508994
#
#        preSnapVisitorTeamWinProbability defensiveTeam  tackle  assist  \
# 1                              0.586653            LA     NaN     NaN
# 2                              0.586653            LA     NaN     NaN
# 5                              0.586653            LA     NaN     NaN
# 6                              0.586653            LA     1.0     0.0
# 7                              0.586653            LA     NaN     NaN
# ...                                 ...           ...     ...     ...
# 97078                          0.491006           SEA     NaN     NaN
# 97079                          0.491006           SEA     0.0     0.0
# 97080                          0.491006           SEA     NaN     NaN
# 97083                          0.491006           SEA     NaN     NaN
# 97085                          0.491006           SEA     NaN     NaN
#
#        forcedFumble  pff_missedTackle  season_rolling_tackle_ct  \
# 1               NaN               NaN                       NaN
# 2               NaN               NaN                       NaN
# 5               NaN               NaN                       NaN
# 6               0.0               0.0                       1.0
# 7               NaN               NaN                       NaN
# ...             ...               ...                       ...
# 97078           NaN               NaN                       NaN
# 97079           0.0               1.0                       3.0
# 97080           NaN               NaN                       NaN
# 97083           NaN               NaN                       NaN
# 97085           NaN               NaN                       NaN
#
#        game_rolling_tackle_ct  season_rolling_missed_tackle_ct  \
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 5                         NaN                              NaN
# 6                         1.0                              0.0
# 7                         NaN                              NaN
# ...                       ...                              ...
# 97078                     NaN                              NaN
# 97079                     3.0                              2.0
# 97080                     NaN                              NaN
# 97083                     NaN                              NaN
# 97085                     NaN                              NaN
#
#        game_rolling_missed_tackle_ct displayName_x_offense  x_offense  \
# 1                                NaN          Stefon Diggs      79.85
# 2                                NaN          Stefon Diggs      79.85
# 5                                NaN          Stefon Diggs      79.85
# 6                                0.0          Stefon Diggs      79.85
# 7                                NaN          Stefon Diggs      79.85
# ...                              ...                   ...        ...
# 97078                            NaN      Javonte Williams      70.57
# 97079                            2.0      Javonte Williams      70.57
# 97080                            NaN      Javonte Williams      70.57
# 97083                            NaN      Javonte Williams      70.57
# 97085                            NaN      Javonte Williams      70.57
#
#        y_offense  s_offense  a_offense  dis_offense  o_offense  dir_offense  \
# 1          35.59       4.61       4.82         0.45     114.27       202.20
# 2          35.59       4.61       4.82         0.45     114.27       202.20
# 5          35.59       4.61       4.82         0.45     114.27       202.20
# 6          35.59       4.61       4.82         0.45     114.27       202.20
# 7          35.59       4.61       4.82         0.45     114.27       202.20
# ...          ...        ...        ...          ...        ...          ...
# 97078      11.96       3.91       2.22         0.39     313.03       192.49
# 97079      11.96       3.91       2.22         0.39     313.03       192.49
# 97080      11.96       3.91       2.22         0.39     313.03       192.49
# 97083      11.96       3.91       2.22         0.39     313.03       192.49
# 97085      11.96       3.91       2.22         0.39     313.03       192.49
#
#        weight_offense position_offense  nflId_offense  height_in_inch_offense  \
# 1                 191               WR        42489.0                      72
# 2                 191               WR        42489.0                      72
# 5                 191               WR        42489.0                      72
# 6                 191               WR        42489.0                      72
# 7                 191               WR        42489.0                      72
# ...               ...              ...            ...                     ...
# 97078             220               RB        53464.0                      70
# 97079             220               RB        53464.0                      70
# 97080             220               RB        53464.0                      70
# 97083             220               RB        53464.0                      70
# 97085             220               RB        53464.0                      70
#
#       position_group_offense position_role_offense  offense_score  \
# 1                          R                    WR              0
# 2                          R                    WR              0
# 5                          R                    WR              0
# 6                          R                    WR              0
# 7                          R                    WR              0
# ...                      ...                   ...            ...
# 97078                     HB                    HB             16
# 97079                     HB                    HB             16
# 97080                     HB                    HB             16
# 97083                     HB                    HB             16
# 97085                     HB                    HB             16
#
#        defense_score  differential  offense_win_prob  defense_win_prob  \
# 1                  0             0          0.586653          0.413347
# 2                  0             0          0.586653          0.413347
# 5                  0             0          0.586653          0.413347
# 6                  0             0          0.586653          0.413347
# 7                  0             0          0.586653          0.413347
# ...              ...           ...               ...               ...
# 97078             17             1          0.491006          0.508994
# 97079             17             1          0.491006          0.508994
# 97080             17             1          0.491006          0.508994
# 97083             17             1          0.491006          0.508994
# 97085             17             1          0.491006          0.508994
#
#        prob_differential  dist_to_bc  is_defense  rank_to_bc
# 1              -0.173306    7.067538           1         3.0
# 2              -0.173306   13.527265           1         9.0
# 5              -0.173306   29.415605           1        11.0
# 6              -0.173306    2.828003           1         1.0
# 7              -0.173306   12.502404           1         6.0
# ...                  ...         ...         ...         ...
# 97078           0.017987   16.352676           1         4.0
# 97079           0.017987    9.983927           1         1.0
# 97080           0.017987   29.283342           1         8.0
# 97083           0.017987   13.167270           1         2.0
# 97085           0.017987   44.540324           1        11.0
#
# [48543 rows x 78 columns]

# %%
# how to handle assists, forced fumbles
#tackle_prob_df['tackle_prob'] = np.where(tackle_prob_df['tackle'] == 1, 1, np.where(tackle_prob_df['assist'] == 1, 0.5, 0))


defensive_players['tackle_prob'] = np.where(defensive_players['tackle'] == 1, 1, 0)
defensive_players.fillna(0, inplace=True)
# Out:
# /var/folders/ys/st95719j0cgg3zkhmr2m_tb80000gn/T/ipykernel_1254/3024795643.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defensive_players['tackle_prob'] = np.where(defensive_players['tackle'] == 1, 1, 0)
# /var/folders/ys/st95719j0cgg3zkhmr2m_tb80000gn/T/ipykernel_1254/3024795643.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defensive_players.fillna(0, inplace=True)

# %% [markdown]
# ## EXPORT DATA

# %%
defensive_players.to_csv('../model/defensive_players.csv', index=False)
